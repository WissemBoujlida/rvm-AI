# %% [markdown]
# #### This lab aims to train and test a classification model using transfer learning capable of classifying the volume and brand of recyclable objects.

# %% [markdown]
# #### The pretrained models used in this lab are part of the Keras Applications Reference. The Keras Applications are deep learning models that are made available alongside pre-trained weights. These models can be used for prediction, feature extraction, and fine-tuning.
# #### URL link : https://keras.io/api/applications/

# %% [markdown]
# #### Within this lab, we will be testing diffrent pretrained models from the Keras Applications. The main goal is to pick up the pretrained model with the heighest performance.

# %% [markdown]
# #### Note : As the data collection phase is not completed yet, and as training more than one model can be computationally expensive, this lab will focus on training and testing only one pretrained model to demonstrate the hole process of training and testing a classification model. Once the data collection phase is completed, then we will proceede with the other models.
# #### The pretrained model implemented within this lab will be the VGG16 model.You can check the keras Applications for more information about this model and other pretrained models as well.

# %%
import os

# %%
# Importing the dataset that will be used to train and test the brand and volume classification model
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-aba3313c9bb0> in <cell line: 3>()
#       1 # Importing the dataset that will be used to train and test the brand and volume classification model
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive', force_remount=True)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     134     )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
# Just Copying the dataset compressed file from the drive folder to the main folder (/content/)
# The dataset contains images that will be used for training and testing the classification model for all the classes(categories) that we want our model to classify
# !cp -r /content/drive/MyDrive/dataset_for_volume_brand_classification.zip .

# %%
# Unzipping the dataset compressed file
# !unzip dataset_for_volume_brand_classification.zip
# Out:
# Archive:  dataset_for_volume_brand_classification.zip
#    creating: dataset_for_volume_brand_classification/
#    creating: dataset_for_volume_brand_classification/BOGA_0.24/
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/boga_0.24i2.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/boga_0.24i3.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/boga_0.24sm2.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/boga_0.24sm3.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/boga_0.24sm8.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/boga_0.245.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_9504.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_428.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_1334.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_4088.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_8796.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_3667.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_9477.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_234.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_2146.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_2598.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_4011.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_1728.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_1880.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_9574.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_3277.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_6792.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_9596.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_3448.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_7444.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_6607.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_6548.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_6892.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_3493.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_7907.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_5159.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_1010.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_6587.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_741.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_7949.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_5651.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_731.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_5693.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_5056.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_3417.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_5516.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_3869.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_736.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_4120.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_3903.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_3950.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_5373.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_6473.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_8889.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_4294.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_6080.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_5447.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_8392.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_9050.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_8993.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_8613.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_4356.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_853.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_5471.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_3565.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_5149.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_7229.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_6146.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_9558.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_2740.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_5749.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_6295.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_5633.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_3500.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_3838.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_6754.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_4486.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_4697.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_6923.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_8966.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_5719.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_1566.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_1188.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_3172.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_3318.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_4366.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_5089.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_7679.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_2356.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_7176.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_1067.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_9590.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_2323.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_7465.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_7219.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_4384.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_5034.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_6917.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_6336.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_9655.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_2018.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_4_1136.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_6683.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_991.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_8953.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_2726.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_8621.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_7328.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_1184.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_4_2391.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_8499.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_3361.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_1404.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_2191.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_1852.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_4_1717.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_4796.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_755.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_3433.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_4_4047.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_3634.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_4_2439.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_5608.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_782.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_4177.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_1022.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_5188.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_1504.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_4_7016.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_6304.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_300.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_7356.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_4_6769.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_4492.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_7623.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_7907.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_4_2856.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_3634.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_8816.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_7293.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_1803.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0_8298.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_1_5248.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_2_542.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_3_7439.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_4_7800.jpg
#   inflating: dataset_for_volume_brand_classification/BOGA_0.24/_0
jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_3867.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_3252.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_1748.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_1981.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_7256.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_6598.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_2222.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_8279.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_7407.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_8780.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_6078.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_6216.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_611.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_5481.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_6175.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_8334.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_3496.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_8903.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_6261.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_5676.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_8255.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_1132.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_9265.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_4561.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_1973.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_9665.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_6088.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_3927.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_4174.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_7739.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_6355.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_9307.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_9677.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_6056.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_6780.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_5404.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_5454.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_9221.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_706.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_3704.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_5306.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_9692.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_9377.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_2920.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_614.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_3286.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_6512.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_1859.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_3807.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_8082.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_619.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_3501.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_5350.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_6940.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_2433.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_274.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_8226.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_1709.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_4681.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_1361.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_3308.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_1697.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_5827.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_2504.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_5_5875.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_2258.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_1720.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_2466.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_5_2619.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_3132.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_2388.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_8422.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_5166.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_7713.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_978.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_2669.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_3778.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_5_7557.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_1660.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_8594.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_5_4431.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_9674.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_5335.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_215.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_5835.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_1950.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_8203.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_1878.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_2340.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_1769.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_8207.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_5_5075.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_3719.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_5614.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_7002.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_1885.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_5_3126.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_165.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_3615.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_3132.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_5_2199.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_1991.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_8615.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_8850.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_3100.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_552.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_6523.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_5_5949.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_7361.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_4200.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_3_2503.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_0_3447.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_1_7781.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_4_9737.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_2_9991.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/_5_67.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_b0.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_b2.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_b3.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_b4.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_b5.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_b6.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_b7.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_b8.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_b9.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_bi0.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_bi2.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_bi3.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_bi4.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_bi5.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_bi6.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_bi7.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_bi8.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_bi9.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sb0.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sb1.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sb2.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sb3.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sb4.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sb5.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sb6.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sb7.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sb8.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sbi0.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sbi2.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sbi3.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sbi4.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sbi5.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sbi6.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sbi7.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sbi8.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sbi9.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sm0.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sm2.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sm3.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sm4.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sm5.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sm6.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sm7.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sm8.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_sm9.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_smi0.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_smi1.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_smi2.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_smi3.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_smi4.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_smi5.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_smi6.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_smi7.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_smi8.jpg
#   inflating: dataset_for_volume_brand_classification/SAFIA_1.5/safia_1.5_smi9.jpg

# %%
# Remove the  compressed dataset file(no need for the compressed files)
# !rm dataset_for_volume_brand_classification.zip

# %%
dataset_directory = 'dataset_for_volume_brand_classification'
dataset_directory
# Out:
# 'dataset_for_volume_brand_classification'

# %%
#These are all the classes(categories) we want our model to classify
classes = os.listdir(dataset_directory)
classes
# Out:
# ['COCA_0.5', 'SAFIA_1.5', 'BOGA_0.24', 'FOURAT_2.0', 'COCA_0.24']

# %% [markdown]
# ## Loading Data

# %%
import numpy as np
import pandas as pd
import cv2

# %%
# hyperparameter
IMG_SIZE = 512

# %%
X = []
y = []

for i, category in enumerate(classes):
    for img in os.listdir(os.path.join(dataset_directory, category)):
        img_path = os.path.join(dataset_directory, category, img)
        X.append(cv2.resize(cv2.imread(img_path), (IMG_SIZE , IMG_SIZE)))
        y.append(i)
X = np.asarray(X)

# %% [markdown]
# ## Scaling Data

# %%
X = X/255.0

# %% [markdown]
# ## Splitting Data

# %%
from sklearn.model_selection import train_test_split

# %%
SPLIT_SIZE = 0.2

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size = SPLIT_SIZE,
    random_state = 42,
    shuffle=True,
    stratify=y
    )

# %%
SPLIT_SIZE = 0.1

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train,
    test_size = SPLIT_SIZE,
    random_state = 42,
    shuffle=True,
    stratify=y_train
    )

# %%
y_train = pd.get_dummies(y_train).values

# %%
y_test = pd.get_dummies(y_test).values

# %%
y_val = pd.get_dummies(y_val).values

# %%
y_train.shape
# Out:
# (864, 5)

# %%
y_test.shape
# Out:
# (240, 5)

# %%
y_val.shape
# Out:
# (96, 5)

# %% [markdown]
# ## Modeling

# %%
import tensorflow as tf
from keras import layers, Model

# %%
model = tf.keras.applications.InceptionV3(
    weights='imagenet',
    input_shape=(512, 512, 3),
    include_top=False,
)
for layer in model.layers:
 layer.trainable = False

last_layer = model.get_layer('mixed7')# Mixed7 is one of the layers in the inception network whose outputs we will use to build the classifier.
last_layer_output = last_layer.output

x = layers.Flatten()(last_layer_output)

x = layers.Dense(64,activation='relu')(x)
x = layers.BatchNormalization()(x)

output = layers.Dense(len(classes), activation='softmax')(x)

model = Model(model.input, output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-32687266ebaa> in <cell line: 1>()
# ----> 1 model = tf.keras.applications.InceptionV3(
#       2     weights='imagenet',
#       3     input_shape=(512, 512, 3),
#       4     include_top=False,
#       5 )
#
# NameError: name 'tf' is not defined

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics='accuracy')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f89eb84d1d5f> in <cell line: 1>()
# ----> 1 model.compile(optimizer='adam', loss='categorical_crossentropy', metrics='accuracy')
#
# NameError: name 'model' is not defined

# %%
model.summary()

# %% [markdown]
# ## Training

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# hyperparameters
EPOCHS = 100
BATCH_SIZE = 8

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('val_accuracy') > 0.99:
            print('\n Validation accuracy = \
            98% so, stopping further training.')
            self.model.stop_training = True


es = EarlyStopping(patience=3,
                   monitor='val_accuracy',
                   restore_best_weights=True)

lr = ReduceLROnPlateau(monitor='val_loss',
                       patience=3,
                       factor=0.5,
                       verbose=1)

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks = [es, lr, myCallback()])

# %%
from matplotlib import pyplot as plt

# %%
fig = plt.figure()

plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()

plt.plot(history.history['accuracy'], color='teal', label='accuracy')
plt.plot(history.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## Testing

# %% [markdown]
# ### Saving the model

# %%
model.save('volume_brand_classification_model')

# %% [markdown]
# ### Convert our model to TFLite
# #### TFLite is a lighter version of our model which can be deployed in an embedded system such as a raspberry pi

# %%
model = tf.keras.models.load_model('volume_brand_classification_model')

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# %%
tflite_model = converter.convert()

# %%
open("volume_brand_classification_model_tflite.tflite", "wb").write(tflite_model)

# %% [markdown]
# ### Compressing and exporting our model

# %%
# !zip -r volume_brand_classification_model.zip volume_brand_classification_model

# %%
# !cp volume_brand_classification_model.zip drive/MyDrive

# %%
# !zip -r volume_brand_classification_model_tflite.zip volume_brand_classification_model_tflite.tflite

# %%
# !cp volume_brand_classification_model_tflite.zip drive/MyDrive
