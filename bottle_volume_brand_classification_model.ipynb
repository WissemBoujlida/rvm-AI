# %% [markdown]
# #### This lab aims to train and test a classification model using transfer learning capable of classifying the volume and brand of recyclable bottles.

# %% [markdown]
# #### The pretrained models used in this lab are part of the Keras Applications Reference. The Keras Applications are deep learning models that are made available alongside pre-trained weights. These models can be used for prediction, feature extraction, and fine-tuning.
# #### URL link : https://keras.io/api/applications/

# %% [markdown]
# #### Within this lab, we will be testing diffrent pretrained models from the Keras Applications. The main goal is to pick up the pretrained model with the heighest performance.

# %% [markdown]
# #### Note : As the data collection phase is not completed yet, and as training more than one model can be computationally expensive, this lab will focus on training and testing only one pretrained model to demonstrate the hole process of training and testing a classification model. Once the data collection phase is completed, then we will proceede with the other models.
# #### The pretrained model implemented within this lab will be the InceptionV3 model.You can check the keras Applications for more information about this model and other pretrained models as well.

# %%
import os

# %%
# Importing the dataset that will be used to train and test the brand and volume classification model
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Just Copying the dataset compressed file from the drive folder to the main folder (/content/)
# The dataset contains images that will be used for training and testing the classification model for all the classes(categories) that we want our model to classify
# !cp -r /content/drive/MyDrive/dataset/dataset_for_bottle_volume_brand_classification_model.zip .

# %%
# Unzipping the dataset compressed file
# !unzip dataset_for_bottle_volume_brand_classification_model.zip
# Out:
# Archive:  dataset_for_bottle_volume_brand_classification_model.zip
#    creating: dataset_for_bottle_volume_brand_classification_model/
#    creating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine_sbsm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine_sbsm20.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine_sbsm2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine_sbsm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine_sbsm21.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine_sbsm4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine_sbsm22.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine_sbsm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine10.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine11.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine12.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine13.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine14.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine_sb1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine_sb2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine_sb3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_AQUALINE/aqualine_sb4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/baya_sbsm02.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/baya_sbsm01.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/baya_sbsm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/baya_sbsm03.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/baya_sbsm00.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/baya_sbsm04.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/baya0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/baya1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/baya1_sb0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/baya1_sb1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/baya2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/baya3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/baya4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/baya_sb1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/baya_sb2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/baya_sb3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_BEYA/baya_sb4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca_sbsm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca_sbsm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca_sbsm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca_sbsm2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca_sb0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca_sb1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca_sb2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca_sb3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca_sb4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca_sm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca_sm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca_sm2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca_sm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_COCA/coca_sm4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/0,5_CRISTALINE/
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_CRISTALINE/cristaline_sbsm2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_CRISTALINE/cristaline_sbsm4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_CRISTALINE/cristaline_sbsm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_CRISTALINE/cristaline_sbsm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_CRISTALINE/cristaline_sbsm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_CRISTALINE/cristaline0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_CRISTALINE/cristaline1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_CRISTALINE/cristaline2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_CRISTALINE/cristaline3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_CRISTALINE/cristaline4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_CRISTALINE/cristaline_sb0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_CRISTALINE/cristaline_sb1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_CRISTALINE/cristaline_sb2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_CRISTALINE/cristaline_sb3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_CRISTALINE/cristaline_sb4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice_sbsm4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice_sb0sm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice_sbsm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice_sbsm2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice_sbsm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice_sb0sm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice_sb0sm4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice_sb0sm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice_sbsm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice5.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice_sb0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice_sb1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice_sb2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice_sb3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DELICE/delice_sb4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/0,5_DIMA/
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DIMA/dima_sbsm2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DIMA/dima_sbsm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DIMA/dima_sbsm4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DIMA/dima_sbsm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DIMA/dima_sbsm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DIMA/dima0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DIMA/dima1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DIMA/dima2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DIMA/dima3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DIMA/dima4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DIMA/dima_sb0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DIMA/dima_sb1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DIMA/dima_sb2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DIMA/dima_sb3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_DIMA/dima_sb4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/0,5_MARWA/
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MARWA/marwa_sbsm00.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MARWA/marwa_sbsm4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MARWA/marwa_sbsm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MARWA/marwa_sbsm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MARWA/marwa_sbsm2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MARWA/marwa_sbsm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MARWA/marwa00.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MARWA/marwa01.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MARWA/marwa2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MARWA/marwa3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MARWA/marwa4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MARWA/marwa_sb0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MARWA/marwa_sb1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MARWA/marwa_sb2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MARWA/marwa_sb3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MARWA/marwa_sb4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/mira2_sbsm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/mira2_sbsm2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/mira2_sbsm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/mira2_sbsm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/mira2_sbsm4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/MIRA_SBSM4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/MIRA_SBSM3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/MIRA_SBSM0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/MIRA_SBSM1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/MIRA_SBSM2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/mira2_sb0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/mira2_sb1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/mira2_sb2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/mira2_sb3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/mira2_sb4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/mira20.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/mira21.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/mira22.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/mira23.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/mira24.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/MIRA_0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/MIRA_1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/MIRA_2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/MIRA_3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/MIRA_SB0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/MIRA_SB1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/MIRA_SB2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/MIRA_SB3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_MIRA/MIRA_SB4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/0,5_ROYALE/
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_ROYALE/royale_sbsm2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_ROYALE/royale_sbsm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_ROYALE/royale_sbsm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_ROYALE/royale_sbsm4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_ROYALE/royale_sbsm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_ROYALE/royale0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_ROYALE/royale1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_ROYALE/royale2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_ROYALE/royale3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_ROYALE/royale4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_ROYALE/royale_sb0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_ROYALE/royale_sb1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_ROYALE/royale_sb2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_ROYALE/royale_sb3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_ROYALE/royale_sb4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia_sb0sm2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia_sb0sm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia_sbsm4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia_sb0sm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia_sbsm2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia_sbsm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia_sbsm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia_sb0sm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia_sbsm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia_sb0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia_sb1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia_sb2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia_sb3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_SAFIA/safia_sb4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/0,5_TIBA/
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIBA/tiba_sbsm4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIBA/tiba_sbsm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIBA/tiba_sbsm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIBA/tiba_sbsm2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIBA/tiba_sbsm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIBA/tiba0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIBA/tiba1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIBA/tiba2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIBA/tiba3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIBA/tiba4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIBA/tiba_sb0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIBA/tiba_sb1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIBA/tiba_sb2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIBA/tiba_sb3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIBA/tiba_sb4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/0,5_TIJEN/
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIJEN/tijen_sbsm4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIJEN/tijen_sbsm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIJEN/tijen_sbsm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIJEN/tijen_sbsm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIJEN/tijen_sbsm2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIJEN/tijen0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIJEN/tijen1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIJEN/tijen2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIJEN/tijen3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIJEN/tijen4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIJEN/tijen_sb0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIJEN/tijen_sb1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIJEN/tijen_sb2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIJEN/tijen_sb3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/0,5_TIJEN/tijen_sb4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsbsm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsbsm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsbsm5.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsbsm2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsbsm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsbsm4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsbsm6.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1L0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1L1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1L2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1L3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1L4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1L5.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1L6.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsb0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsb1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsb2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsb3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsb4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsb5.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsb6.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsbm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsbm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsbm2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsbm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsbm4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsbm5.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_COCA/coca_1Lsbm6.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/1,0_MIRA/
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_MIRA/mira0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_MIRA/mira1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_MIRA/mira2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_MIRA/mira3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_MIRA/mira4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_MIRA/mira_sb0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_MIRA/mira_sb1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_MIRA/mira_sb2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_MIRA/mira_sb3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,0_MIRA/mira_sb4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/1,5_BARGOU/
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BARGOU/BARGOU_1.5LSBSM4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BARGOU/BARGOU_1.5LSBSM2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BARGOU/BARGOU_1.5LSBSM0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BARGOU/BARGOU_1.5LSBSM1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BARGOU/BARGOU_1.5LSBSM3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BARGOU/BARGOU_1.5L0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BARGOU/BARGOU_1.5L1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BARGOU/BARGOU_1.5L2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BARGOU/BARGOU_1.5L3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BARGOU/BARGOU_1.5L4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BARGOU/BARGOU_1.5LSB0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BARGOU/BARGOU_1.5LSB1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BARGOU/BARGOU_1.5LSB2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BARGOU/BARGOU_1.5LSB3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BARGOU/BARGOU_1.5LSB4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/1,5_BOGACIDRE/
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BOGACIDRE/BOGA_1.5LSBSM3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BOGACIDRE/BOGA_1.5LSBSM2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BOGACIDRE/BOGA_1.5LSBSM0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BOGACIDRE/BOGA_1.5LSBSM4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BOGACIDRE/BOGA_1.5LSBSM1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BOGACIDRE/BOGA_1.5L0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BOGACIDRE/BOGA_1.5L1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BOGACIDRE/BOGA_1.5L2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BOGACIDRE/BOGA_1.5L3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BOGACIDRE/BOGA_1.5L4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BOGACIDRE/BOGA_1.5LSB0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BOGACIDRE/BOGA_1.5LSB1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BOGACIDRE/BOGA_1.5LSB2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BOGACIDRE/BOGA_1.5LSB3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BOGACIDRE/BOGA_1.5LSB4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_BOGACIDRE/DELICE_1.5LSB2.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/1,5_DELICE/
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_DELICE/DELICE_1.5LSMSB04.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_DELICE/DELICE_1.5LSMSB00.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_DELICE/DELICE_1.5LSMSB01.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_DELICE/DELICE_1.5LSMSB02.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_DELICE/DELICE_1.5LSMSB03.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_DELICE/DELICE_1.5L00.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_DELICE/DELICE_1.5L01.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_DELICE/DELICE_1.5L02.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_DELICE/DELICE_1.5L03.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_DELICE/DELICE_1.5L04.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_DELICE/DELICE_1.5LSB0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_DELICE/DELICE_1.5LSB1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_DELICE/DELICE_1.5LSB4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/1,5_MARWA/
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MARWA/marwa_1.5LSBSM3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MARWA/marwa_1.5LSBSM1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MARWA/marwa_1.5LSBSM0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MARWA/marwa_1.5LSBSM4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MARWA/marwa_1.5LSBSM2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MARWA/marwa_1.5L0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MARWA/marwa_1.5L1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MARWA/marwa_1.5L2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MARWA/marwa_1.5L3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MARWA/marwa_1.5L4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MARWA/marwa_1.5LSB0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MARWA/marwa_1.5LSB1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MARWA/marwa_1.5LSB2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MARWA/marwa_1.5LSB3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MARWA/marwa_1.5LSB4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5LSBSM23.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5LSBSM3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5LSBSM4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5LSBSM24.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5LSBSM22.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5LSBSM21.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5LSBSM2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5LSBSM0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5LSBSM1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5LSBSM20.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5L0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5L1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5L2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5L3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5L4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5LSB0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5LSB1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5LSB2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5LSB3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_MELLITI/MELITI_1.5LSB4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/1,5_SABRINE/
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SABRINE/sabrine_1.5Lsbsm2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SABRINE/sabrine_1.5Lsbsm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SABRINE/sabrine_1.5Lsbsm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SABRINE/sabrine_1.5Lsbsm4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SABRINE/sabrine_1.5Lsbsm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SABRINE/sabrine_1.5L0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SABRINE/sabrine_1.5L1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SABRINE/sabrine_1.5L2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SABRINE/sabrine_1.5L3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SABRINE/sabrine_1.5L4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SABRINE/sabrine_1.5Lsb0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SABRINE/sabrine_1.5Lsb1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SABRINE/sabrine_1.5Lsb2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SABRINE/sabrine_1.5Lsb3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SABRINE/sabrine_1.5Lsb4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/SAFIA_1.5LSBSM4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/SAFIA_1.5LSBSM3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/SAFIA_1.5LSBSM2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/SAFIA_1.5LSBSM1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/SAFIA_1.5LSBSM0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/SAFIA_1.5L0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/SAFIA_1.5L1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/SAFIA_1.5L2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/SAFIA_1.5L3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/SAFIA_1.5L4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/SAFIA_1.5L50.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/SAFIA_1.5LSB0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/SAFIA_1.5LSB1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/SAFIA_1.5LSB2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/SAFIA_1.5LSB3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/SAFIA_1.5LSB4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_SAFIA/SAFIA_1.5L1 (copy).jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5Lsbsm24.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5Lsbsm22.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5Lsbsm21.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5Lsbsm23.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5Lsbsm2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5Lsbsm1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5Lsbsm3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5Lsbsm20.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5Lsbsm4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5Lsbsm0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5L0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5L1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5L2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5L3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5L4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5Lsb0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5Lsb1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5Lsb2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5Lsb3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/1,5_TIJEN/tijen_1.5Lsb4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/2,0_DENYA/
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DENYA/DENIA_2LSBSM1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DENYA/DENIA_2LSBSM4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DENYA/DENIA_2LSBSM3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DENYA/DENIA_2LSBSM2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DENYA/DENIA_2L0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DENYA/DENIA_2L1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DENYA/DENIA_2L2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DENYA/DENIA_2L3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DENYA/DENIA_2L4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DENYA/DENIA_2LSB0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DENYA/DENIA_2LSB1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DENYA/DENIA_2LSB2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DENYA/DENIA_2LSB3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DENYA/DENIA_2LSB4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/2,0_DIMA/
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DIMA/DIMA_2LSBSM4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DIMA/DIMA_2LSBSM0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DIMA/DIMA_2LSBSM3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DIMA/DIMA_2LSBSM1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DIMA/DIMA_2LSBSM2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DIMA/DIMA_2L0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DIMA/DIMA_2L1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DIMA/DIMA_2L2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DIMA/DIMA_2L3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DIMA/DIMA_2L4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DIMA/DIMA_2LSB0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DIMA/DIMA_2LSB1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DIMA/DIMA_2LSB3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_DIMA/DIMA_2LSB4.jpg
#    creating: dataset_for_bottle_volume_brand_classification_model/2,0_FOURAT/
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_FOURAT/FOURAT_2LSBSM0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_FOURAT/FOURAT_2LSBSM4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_FOURAT/FOURAT_2LSBSM2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_FOURAT/FOURAT_2LSBSM1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_FOURAT/FOURAT_2LSBSM3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_FOURAT/FOURAT_2L0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_FOURAT/FOURAT_2L1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_FOURAT/FOURAT_2L2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_FOURAT/FOURAT_2L3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_FOURAT/FOURAT_2L4.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_FOURAT/FOURAT_2LSB0.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_FOURAT/FOURAT_2LSB1.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_FOURAT/FOURAT_2LSB2.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_FOURAT/FOURAT_2LSB3.jpg
#   inflating: dataset_for_bottle_volume_brand_classification_model/2,0_FOURAT/FOURAT_2LSB4.jpg

# %%
# Remove the compressed dataset file(no need for the compressed files)
# !rm dataset_for_bottle_volume_brand_classification_model.zip

# %%
dataset_directory = 'dataset_for_bottle_volume_brand_classification_model'
dataset_directory
# Out:
# 'dataset_for_bottle_volume_brand_classification_model'

# %%
#These are all the classes(categories) we want our model to classify
classes = os.listdir(dataset_directory)
classes
# Out:
# ['1,5_SAFIA',
#  '1,5_DELICE',
#  '0,5_DELICE',
#  '1,0_MIRA',
#  '1,0_COCA',
#  '1,5_MELLITI',
#  '2,0_DIMA',
#  '0,5_TIBA',
#  '0,5_SAFIA',
#  '0,5_MIRA',
#  '0,5_BEYA',
#  '0,5_CRISTALINE',
#  '0,5_MARWA',
#  '0,5_ROYALE',
#  '2,0_DENYA',
#  '0,5_TIJEN',
#  '0,5_COCA',
#  '1,5_MARWA',
#  '1,5_BARGOU',
#  '0,5_AQUALINE',
#  '0,5_DIMA',
#  '1,5_SABRINE',
#  '1,5_TIJEN',
#  '1,5_BOGACIDRE',
#  '2,0_FOURAT']

# %% [markdown]
# ## Loading Data

# %%
import numpy as np
import pandas as pd
import cv2

# %%
# hyperparameter
IMG_SIZE = 512

# %%
X = []
y = []

for i, category in enumerate(classes):
    for img in os.listdir(os.path.join(dataset_directory, category)):
        img_path = os.path.join(dataset_directory, category, img)
        X.append(cv2.resize(cv2.imread(img_path), (IMG_SIZE , IMG_SIZE)))
        y.append(i)
X = np.asarray(X)

# %% [markdown]
# ## Scaling Data

# %%
X = X/255.0

# %% [markdown]
# ## Splitting Data

# %%
from sklearn.model_selection import train_test_split

# %%
SPLIT_SIZE = 0.2

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size = SPLIT_SIZE,
    random_state = 42,
    shuffle=True,
    stratify=y
    )

# %%
SPLIT_SIZE = 0.1

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train,
    test_size = SPLIT_SIZE,
    random_state = 42,
    shuffle=True,
    stratify=y_train
    )

# %%
y_train = pd.get_dummies(y_train).values

# %%
y_test = pd.get_dummies(y_test).values

# %%
y_val = pd.get_dummies(y_val).values

# %%
y_train.shape
# Out:
# (306, 25)

# %%
y_test.shape
# Out:
# (86, 25)

# %%
y_val.shape
# Out:
# (35, 25)

# %% [markdown]
# ## Modeling

# %%
import tensorflow as tf
from keras import layers, Model

# %%
model = tf.keras.applications.InceptionV3(
    weights='imagenet',
    input_shape=(512, 512, 3),
    include_top=False,
)
for layer in model.layers:
 layer.trainable = False

last_layer = model.get_layer('mixed7')# Mixed7 is one of the layers in the inception network whose outputs we will use to build the classifier.
last_layer_output = last_layer.output

x = layers.Flatten()(last_layer_output)

x = layers.Dense(256,activation='relu')(x)
x = layers.BatchNormalization()(x)

output = layers.Dense(len(classes), activation='softmax')(x)

model = Model(model.input, output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics='accuracy')

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 255, 255, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 255, 255, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 255, 255, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 253, 253, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 253, 253, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 253, 253, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 253, 253, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 253, 253, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 253, 253, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 126, 126, 64  0           ['activation_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 126, 126, 80  5120        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 126, 126, 80  240        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 126, 126, 80  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 124, 124, 19  138240      ['activation_3[0][0]']
#                                 2)
#
#  batch_normalization_4 (BatchNo  (None, 124, 124, 19  576        ['conv2d_4[0][0]']
#  rmalization)                   2)
#
#  activation_4 (Activation)      (None, 124, 124, 19  0           ['batch_normalization_4[0][0]']
#                                 2)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 61, 61, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 61, 61, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 61, 61, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 61, 61, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 61, 61, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 61, 61, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 61, 61, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 61, 61, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 61, 61, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 61, 61, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 61, 61, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 61, 61, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 61, 61, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 61, 61, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 61, 61, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 61, 61, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 61, 61, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 61, 61, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 61, 61, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 61, 61, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 61, 61, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 61, 61, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 61, 61, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 61, 61, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 61, 61, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 61, 61, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 61, 61, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 61, 61, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 61, 61, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 61, 61, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 61, 61, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 61, 61, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 61, 61, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 61, 61, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 61, 61, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 61, 61, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 61, 61, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 61, 61, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 61, 61, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 61, 61, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 61, 61, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 61, 61, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 61, 61, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 61, 61, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 61, 61, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 61, 61, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 61, 61, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 61, 61, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 61, 61, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 61, 61, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 61, 61, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 61, 61, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 61, 61, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 61, 61, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 61, 61, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 61, 61, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 61, 61, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 61, 61, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 61, 61, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 61, 61, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 61, 61, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 61, 61, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 61, 61, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 61, 61, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 61, 61, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 61, 61, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 30, 30, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 30, 30, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 30, 30, 384)  1152       ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 30, 30, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 30, 30, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 30, 30, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 30, 30, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 30, 30, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 30, 30, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 30, 30, 128)  384        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 30, 30, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 30, 30, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 30, 30, 128)  384        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 30, 30, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 30, 30, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 30, 30, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 30, 30, 128)  384        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 30, 30, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 30, 30, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 30, 30, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 30, 30, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 30, 30, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 30, 30, 128)  384        ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 30, 30, 128)  384        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 30, 30, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 30, 30, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 30, 30, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 30, 30, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 30, 30, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 30, 30, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 30, 30, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 30, 30, 192)  576        ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 30, 30, 192)  576        ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 30, 30, 192)  576        ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 30, 30, 192)  576        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 30, 30, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 30, 30, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 30, 30, 160)  480        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 30, 30, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 30, 30, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 30, 30, 160)  480        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 30, 30, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 30, 30, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 30, 30, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 30, 30, 160)  480        ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 30, 30, 160)  480        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 30, 30, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 30, 30, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 30, 30, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 30, 30, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 30, 30, 160)  480        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 30, 30, 160)  480        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 30, 30, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 30, 30, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 30, 30, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 30, 30, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 30, 30, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 30, 30, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 30, 30, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 30, 30, 192)  576        ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 30, 30, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 30, 30, 192)  576        ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 30, 30, 192)  576        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 30, 30, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 30, 30, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 30, 30, 160)  480        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 30, 30, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 30, 30, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 30, 30, 160)  480        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 30, 30, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 30, 30, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 30, 30, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 30, 30, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 30, 30, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 30, 30, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 30, 30, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 30, 30, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 30, 30, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 30, 30, 160)  480        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 30, 30, 160)  480        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 30, 30, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 30, 30, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 30, 30, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 30, 30, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 30, 30, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 30, 30, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 30, 30, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 30, 30, 192)  576        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 30, 30, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 30, 30, 192)  576        ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 30, 30, 192)  576        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_59[0][0]']
#
#  mixed6 (Concatenate)           (None, 30, 30, 768)  0           ['activation_50[0][0]',
#                                                                   'activation_53[0][0]',
#                                                                   'activation_58[0][0]',
#                                                                   'activation_59[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 30, 30, 192)  147456      ['mixed6[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 30, 30, 192)  576        ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_64[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 30, 30, 192)  258048      ['activation_64[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 30, 30, 192)  576        ['conv2d_65[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_65[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 30, 30, 192)  147456      ['mixed6[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 30, 30, 192)  258048      ['activation_65[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 30, 30, 192)  576        ['conv2d_61[0][0]']
#  ormalization)
#
#  batch_normalization_66 (BatchN  (None, 30, 30, 192)  576        ['conv2d_66[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_61[0][0]']
#
#  activation_66 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_66[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 30, 30, 192)  258048      ['activation_61[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 30, 30, 192)  258048      ['activation_66[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 30, 30, 192)  576        ['conv2d_62[0][0]']
#  ormalization)
#
#  batch_normalization_67 (BatchN  (None, 30, 30, 192)  576        ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_62[0][0]']
#
#  activation_67 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_67[0][0]']
#
#  average_pooling2d_6 (AveragePo  (None, 30, 30, 768)  0          ['mixed6[0][0]']
#  oling2D)
#
#  conv2d_60 (Conv2D)             (None, 30, 30, 192)  147456      ['mixed6[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 30, 30, 192)  258048      ['activation_62[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 30, 30, 192)  258048      ['activation_67[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 30, 30, 192)  147456      ['average_pooling2d_6[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 30, 30, 192)  576        ['conv2d_60[0][0]']
#  ormalization)
#
#  batch_normalization_63 (BatchN  (None, 30, 30, 192)  576        ['conv2d_63[0][0]']
#  ormalization)
#
#  batch_normalization_68 (BatchN  (None, 30, 30, 192)  576        ['conv2d_68[0][0]']
#  ormalization)
#
#  batch_normalization_69 (BatchN  (None, 30, 30, 192)  576        ['conv2d_69[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_60[0][0]']
#
#  activation_63 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_63[0][0]']
#
#  activation_68 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_68[0][0]']
#
#  activation_69 (Activation)     (None, 30, 30, 192)  0           ['batch_normalization_69[0][0]']
#
#  mixed7 (Concatenate)           (None, 30, 30, 768)  0           ['activation_60[0][0]',
#                                                                   'activation_63[0][0]',
#                                                                   'activation_68[0][0]',
#                                                                   'activation_69[0][0]']
#
#  flatten (Flatten)              (None, 691200)       0           ['mixed7[0][0]']
#
#  dense (Dense)                  (None, 256)          176947456   ['flatten[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 256)         1024        ['dense[0][0]']
#  ormalization)
#
#  dense_1 (Dense)                (None, 25)           6425        ['batch_normalization_94[0][0]']
#
# ==================================================================================================
# Total params: 185,930,169
# Trainable params: 176,954,393
# Non-trainable params: 8,975,776
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# hyperparameters
EPOCHS = 10
BATCH_SIZE = 8

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('val_accuracy') > 0.98:
            print('\n Validation accuracy = \
            98% so, stopping further training.')
            self.model.stop_training = True


es = EarlyStopping(patience=3,
                   monitor='val_accuracy',
                   restore_best_weights=True)

lr = ReduceLROnPlateau(monitor='val_loss',
                       patience=3,
                       factor=0.5,
                       verbose=1)

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks = [es, lr, myCallback()])
# Out:
# Epoch 1/10
# 39/39 [==============================] - 181s 5s/step - loss: 1.5252 - accuracy: 0.6144 - val_loss: 1.1858 - val_accuracy: 0.6571 - lr: 0.0010
# Epoch 2/10
# 39/39 [==============================] - 171s 4s/step - loss: 0.2804 - accuracy: 0.9739 - val_loss: 0.4329 - val_accuracy: 0.8857 - lr: 0.0010
# Epoch 3/10
# 39/39 [==============================] - 177s 5s/step - loss: 0.0937 - accuracy: 1.0000 - val_loss: 0.2203 - val_accuracy: 0.9429 - lr: 0.0010
# Epoch 4/10
# 39/39 [==============================] - 173s 4s/step - loss: 0.0609 - accuracy: 1.0000 - val_loss: 0.2688 - val_accuracy: 0.9429 - lr: 0.0010
# Epoch 5/10
# 39/39 [==============================] - 176s 5s/step - loss: 0.0457 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.9429 - lr: 0.0010
# Epoch 6/10
# 39/39 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9967
#  Validation accuracy =             98% so, stopping further training.
# 39/39 [==============================] - 190s 5s/step - loss: 0.0545 - accuracy: 0.9967 - val_loss: 0.1301 - val_accuracy: 0.9714 - lr: 0.0010

# %%
from matplotlib import pyplot as plt

# %%
fig = plt.figure()

plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()

plt.plot(history.history['accuracy'], color='teal', label='accuracy')
plt.plot(history.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## Testing

# %%
from sklearn import metrics

# %%
y_test = np.argmax(y_test, axis=1)

# %%
y_pred = model.predict(X_test)
# Out:
# 3/3 [==============================] - 29s 8s/step

# %%
y_pred = np.argmax(y_pred, axis=1)

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         6
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         3
#            7       0.75      1.00      0.86         3
#            8       0.80      1.00      0.89         4
#            9       1.00      0.83      0.91         6
#           10       1.00      1.00      1.00         3
#           11       1.00      1.00      1.00         3
#           12       1.00      1.00      1.00         3
#           13       1.00      0.67      0.80         3
#           14       1.00      1.00      1.00         3
#           15       1.00      1.00      1.00         3
#           16       1.00      1.00      1.00         4
#           17       0.75      1.00      0.86         3
#           18       1.00      1.00      1.00         3
#           19       1.00      1.00      1.00         4
#           20       1.00      1.00      1.00         3
#           21       1.00      1.00      1.00         3
#           22       1.00      0.75      0.86         4
#           23       1.00      1.00      1.00         3
#           24       1.00      1.00      1.00         3
#
#     accuracy                           0.97        86
#    macro avg       0.97      0.97      0.97        86
# weighted avg       0.97      0.97      0.96        86

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### Saving the model

# %%
model.save('bottle_volume_brand_classification_model')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 71). These functions will not be directly callable after loading.

# %% [markdown]
# ### Convert our model to TFLite
# #### TFLite is a lighter version of our model which can be deployed in an embedded system such as a raspberry pi

# %%
model = tf.keras.models.load_model('bottle_volume_brand_classification_model')

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# %%
tflite_model = converter.convert()
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 71). These functions will not be directly callable after loading.

# %%
open("bottle_volume_brand_classification_model_tflite.tflite", "wb").write(tflite_model)
# Out:
# 743679888

# %% [markdown]
# ### Compressing and exporting our model

# %%
# !zip -r bottle_volume_brand_classification_model.zip bottle_volume_brand_classification_model
# Out:
#   adding: bottle_volume_brand_classification_model/ (stored 0%)
#   adding: bottle_volume_brand_classification_model/saved_model.pb (deflated 92%)
#   adding: bottle_volume_brand_classification_model/assets/ (stored 0%)
#   adding: bottle_volume_brand_classification_model/keras_metadata.pb (deflated 96%)
#   adding: bottle_volume_brand_classification_model/fingerprint.pb (stored 0%)
#   adding: bottle_volume_brand_classification_model/variables/ (stored 0%)
#   adding: bottle_volume_brand_classification_model/variables/variables.index (deflated 78%)
#   adding: bottle_volume_brand_classification_model/variables/variables.data-00000-of-00001 (deflated 36%)

# %%
# !cp -r bottle_volume_brand_classification_model.zip drive/MyDrive

# %%
# !zip -r bottle_volume_brand_classification_model_tflite.zip bottle_volume_brand_classification_model_tflite.tflite
# Out:
#   adding: bottle_volume_brand_classification_model_tflite.tflite (deflated 8%)

# %%
# !cp bottle_volume_brand_classification_model_tflite.zip drive/MyDrive
